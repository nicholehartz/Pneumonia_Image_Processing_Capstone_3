# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.ndimage as ndi

# %%
df_train = pd.read_pickle('Clean_Data/training_data.csv')

df_test = pd.read_pickle('Clean_Data/testing_data.csv')

df_val = pd.read_pickle('Clean_Data/validation_data.csv')

# %%
print(df_train.head(3))
print(df_test.head(3))
print(df_val.head(3))
# Out:
#                                                Image   Label
# 0  [[29, 27, 30, 28, 27, 26, 28, 29, 30, 29, 28, ...  Normal
# 1  [[107, 58, 53, 47, 50, 81, 84, 83, 97, 93, 106...  Normal
# 2  [[44, 57, 69, 75, 83, 89, 93, 96, 104, 106, 17...  Normal
#                                                Image   Label
# 0  [[25, 24, 21, 19, 19, 21, 20, 21, 20, 20, 20, ...  Normal
# 1  [[1, 3, 3, 6, 4, 6, 6, 5, 6, 6, 7, 5, 7, 6, 8,...  Normal
# 2  [[68, 80, 58, 54, 56, 49, 42, 32, 21, 0, 0, 1,...  Normal
#                                                Image   Label
# 0  [[6, 23, 32, 30, 40, 37, 44, 43, 40, 38, 39, 4...  Normal
# 1  [[1, 3, 20, 16, 13, 37, 41, 41, 51, 55, 60, 61...  Normal
# 2  [[2, 104, 88, 98, 105, 117, 117, 126, 122, 126...  Normal

# %%
print(df_train.shape)
print(df_test.shape)
print(df_val.shape)
# Out:
# (5216, 2)
# (624, 2)
# (16, 2)

# %%
_ = plt.imshow(df_train['Image'][0], cmap='gray')
_ = plt.axis('off')
_ = plt.title('Image 1')

# %%
df_train['Image'][0].shape
# Out:
# (150, 150)

# %% [markdown]
# ## Split Data

# %%
X_train = df_train['Image']
y_train = df_train['Label']

X_test = df_test['Image']
y_test = df_test['Label']

X_val = df_val['Image']
y_val = df_val['Label']

# %%
print('Training data shape : ', X_train.shape, y_train.shape)
# Out:
# Training data shape :  (5216,) (5216,)

# %% [markdown]
# ## Preprocess Data

# %%
X_train = X_train.reshape(-1, 150,150, 1)
X_test = X_test['Image'].reshape(-1, 150,150, 1)
X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f6e777b93da6> in <module>
# ----> 1 X_train = X_train.reshape(-1, 150,150, 1)
#       2 X_test = X_test['Image'].reshape(-1, 150,150, 1)
#       3 X_train.shape, X_test.shape
#
# ~/opt/anaconda3/envs/TestEnv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %% [markdown]
# ### Equalize Images

# %%
# Define function to equalize list of images
def im_equalize(df_col, df_new_col):
    im_equalized = []
    for im in range(len(df_col)):
        hist = ndi.histogram(df_col[im], min=0, max=255, bins=256)
        cdf = hist.cumsum() / hist.sum()
        im_equalized.append(cdf[df_col[im]] * 255)
    df_new_col = im_equalized

# %%
# Verify im_equalize function works
im_equalize(df_train['Image'], df_train['Image_Equalized'])

_ = plt.imshow(df_train['Image'][42], cmap='gray')
_ = plt.title('Original')
_ = plt.axis('off')
plt.show()

_ = plt.imshow(df_train['Image_Equalized'][42], cmap='gray')
_ = plt.title('Equalized')
_ = plt.axis('off')
plt.show()

# %% [markdown]
# ## Model

# %%
model = Sequential()
